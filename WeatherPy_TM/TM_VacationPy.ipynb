# %%
#pip install gmaps

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

gmaps.configure(api_key=g_key)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Customize the size of the figure
figure_layout = {
    'width': '800px',
    'height': '800px',
    'border': '1px solid black',
    #'padding': '.1px',
    #'margin': '0 auto 0 auto'
}
fig = gmaps.figure()

# %%
clean_city_data = pd.read_csv('output_data/WeatherPy_cities.csv')

# %%
# Code to map cities in the list

cities = clean_city_data[["Lat","Lng"]]

heat_index = clean_city_data["Humidity"].astype(float)

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(cities, weights=heat_index, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hotspots = clean_city_data.loc[(clean_city_data["Max Temp"]>=75) & (clean_city_data["Cloudiness"]<=35) & (clean_city_data["Windspeed"]<=4.0)]
hotspots
# Out:
#      Unnamed: 0             City    Lat     Lng  Max Temp  Cloudiness  \
# 45           45  Manavālakurichi   8.13   77.30     78.80          20
# 58           58        Oriximiná  -1.77  -55.87     82.81          26
# 76           76           Ranong   9.97   98.63     75.20          20
# 79           79           Kupang -10.17  123.58     89.83           6
# 83           83     Saint George  37.10 -113.58     75.20           1
# 136         136        Huaicheng  23.91  112.19     76.93           0
# 230         230             Bima  -8.47  118.72     88.97           6
# 258         258            Airai  -8.93  125.41     75.69           0
# 274         274         Santarém  -2.44  -54.71     78.80           0
# 309         309        Namatanai  -3.67  152.43     86.11          26
# 323         323   Port Macquarie -31.43  152.92     78.01           6
# 327         327     Coolum Beach -26.53  153.10     84.00           0
# 442         442      Barreirinha  -2.79  -57.07     82.51          35
# 474         474           Laguna  38.42 -121.42     78.80           1
# 512         512       Singaparna  -7.35  108.11     79.61           6
#
#      Windspeed        Date Country  Humidity
# 45        3.89  1604191971      IN       100
# 58        3.06  1604191973      BR        51
# 76        1.23  1604192098      TH       100
# 79        2.10  1604192099      ID        42
# 83        1.77  1604192021      US        13
# 136       1.34  1604192231      CN        63
# 230       2.53  1604192371      ID        51
# 258       3.24  1604192498      TL        37
# 274       3.36  1604192502      BR        94
# 309       3.96  1604192632      PG        66
# 323       3.00  1604192416      AU        45
# 327       1.99  1604192636      AU        37
# 442       1.72  1604192923      BR        49
# 474       3.98  1604192739      US        22
# 512       1.43  1604193058      ID        73

# %%
clean_city_data.drop(clean_city_data.loc[(clean_city_data["Max Temp"]<75) | (clean_city_data["Cloudiness"]>35) | (clean_city_data["Windspeed"]>4.0)].index, inplace=True)

# %%
clean_city_data
# Out:
#      Unnamed: 0             City    Lat     Lng  Max Temp  Cloudiness  \
# 45           45  Manavālakurichi   8.13   77.30     78.80          20
# 58           58        Oriximiná  -1.77  -55.87     82.81          26
# 76           76           Ranong   9.97   98.63     75.20          20
# 79           79           Kupang -10.17  123.58     89.83           6
# 83           83     Saint George  37.10 -113.58     75.20           1
# 136         136        Huaicheng  23.91  112.19     76.93           0
# 230         230             Bima  -8.47  118.72     88.97           6
# 258         258            Airai  -8.93  125.41     75.69           0
# 274         274         Santarém  -2.44  -54.71     78.80           0
# 309         309        Namatanai  -3.67  152.43     86.11          26
# 323         323   Port Macquarie -31.43  152.92     78.01           6
# 327         327     Coolum Beach -26.53  153.10     84.00           0
# 442         442      Barreirinha  -2.79  -57.07     82.51          35
# 474         474           Laguna  38.42 -121.42     78.80           1
# 512         512       Singaparna  -7.35  108.11     79.61           6
#
#      Windspeed        Date Country  Humidity
# 45        3.89  1604191971      IN       100
# 58        3.06  1604191973      BR        51
# 76        1.23  1604192098      TH       100
# 79        2.10  1604192099      ID        42
# 83        1.77  1604192021      US        13
# 136       1.34  1604192231      CN        63
# 230       2.53  1604192371      ID        51
# 258       3.24  1604192498      TL        37
# 274       3.36  1604192502      BR        94
# 309       3.96  1604192632      PG        66
# 323       3.00  1604192416      AU        45
# 327       1.99  1604192636      AU        37
# 442       1.72  1604192923      BR        49
# 474       3.98  1604192739      US        22
# 512       1.43  1604193058      ID        73

# %%
locations = clean_city_data[["City","Country","Lat","Lng","Humidity"]]
locations["Hotel Name"] = ""
locations
# Out:
#                 City Country    Lat     Lng  Humidity Hotel Name
# 45   Manavālakurichi      IN   8.13   77.30       100
# 58         Oriximiná      BR  -1.77  -55.87        51
# 76            Ranong      TH   9.97   98.63       100
# 79            Kupang      ID -10.17  123.58        42
# 83      Saint George      US  37.10 -113.58        13
# 136        Huaicheng      CN  23.91  112.19        63
# 230             Bima      ID  -8.47  118.72        51
# 258            Airai      TL  -8.93  125.41        37
# 274         Santarém      BR  -2.44  -54.71        94
# 309        Namatanai      PG  -3.67  152.43        66
# 323   Port Macquarie      AU -31.43  152.92        45
# 327     Coolum Beach      AU -26.53  153.10        37
# 442      Barreirinha      BR  -2.79  -57.07        49
# 474           Laguna      US  38.42 -121.42        22
# 512       Singaparna      ID  -7.35  108.11        73

# %%
coordinates = clean_city_data[["Lat","Lng"]]

# %%
humidity = locations["Humidity"].astype(float)

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
heatlayer = gmaps.heatmap_layer(coordinates, weights=humidity, max_intensity=10, point_radius=2)
fig.add_layer(heatlayer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
params = {
    "radius" : 5000,
    "types" : "lodging",
    "key" : g_key,
    }
for index, row in locations.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"]=f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    address = requests.get(base_url,params=params)
    address = address.json()
    try:
        locations.loc[index,"Hotel Name"]=address["results"][0]["name"]
    except (IndexError,KeyError):
        print("Not found, skipping...")
        
locations
# Out:
#                 City Country    Lat     Lng  Humidity  \
# 45   Manavālakurichi      IN   8.13   77.30       100
# 58         Oriximiná      BR  -1.77  -55.87        51
# 76            Ranong      TH   9.97   98.63       100
# 79            Kupang      ID -10.17  123.58        42
# 83      Saint George      US  37.10 -113.58        13
# 136        Huaicheng      CN  23.91  112.19        63
# 230             Bima      ID  -8.47  118.72        51
# 258            Airai      TL  -8.93  125.41        37
# 274         Santarém      BR  -2.44  -54.71        94
# 309        Namatanai      PG  -3.67  152.43        66
# 323   Port Macquarie      AU -31.43  152.92        45
# 327     Coolum Beach      AU -26.53  153.10        37
# 442      Barreirinha      BR  -2.79  -57.07        49
# 474           Laguna      US  38.42 -121.42        22
# 512       Singaparna      ID  -7.35  108.11        73
#
#                                             Hotel Name
# 45                                   Udaya Boys Hostel
# 58                                  Pousada Tia Amélia
# 76                                Tinidee Hotel@Ranong
# 79                         Sylvia Hotel Premier Kupang
# 83                         Best Western Plus Abbey Inn
# 136                                       Tengye Hotel
# 230                                      Lambitu Hotel
# 258                                     Juvinal Martin
# 274                                    Hotel Imperador
# 309                                    Namatanai Hotel
# 323                              Rydges Port Macquarie
# 327                               Palmer Coolum Resort
# 442                   Hotel e Restaurante Tupana Iwato
# 474  Holiday Inn Express & Suites Elk Grove Central...
# 512                          H. maman Sukirman "Koran"

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in locations.iterrows()]
points = locations[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(points,info_box_content=hotel_info)
fig.add_layer(marker_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
